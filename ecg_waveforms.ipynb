# %%
import os

# %%
os.chdir("ptb-diagnostic-ecg-database-1.0.0")

# %%
z= os.walk(top='')

# %%
z=[]
for dirname, _, filenames in os.walk('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/'):
    for filename in filenames:
        z.append((os.path.join(dirname, filename)))

# %%
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import shutil

import wfdb

# %%
record = wfdb.rdrecord("/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0077lre") 
wfdb.plot_wfdb(record=record, title='Record a103l from Physionet Challenge 2015') 
display(record.__dict__)
# Out:
# {'record_name': 's0077lre',
#  'n_sig': 15,
#  'fs': 1000,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 115200,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['age: 57',
#   'sex: male',
#   'ECG date: 17/12/1990',
#   'Diagnose:',
#   'Reason for admission: Myocardial infarction',
#   'Acute infarction (localization): infero-lateral',
#   'Former infarction (localization): no',
#   'Additional diagnoses: Arterial hypertension, Hyperlipoproteinemia Typ IIa, Obesity',
#   'Smoker: yes',
#   'Number of coronary vessels involved: 1',
#   'Infarction date (acute): 24-Nov-90',
#   'Previous infarction (1) date: n/a',
#   'Previous infarction (2) date: n/a',
#   'Hemodynamics:',
#   'Catheterization date: 03-Dec-90',
#   'Ventriculography: Hypokinesia inferior wall and apex',
#   'Chest X-ray: Heart size upper limit of norm',
#   'Peripheral blood Pressure (syst/diast):  110/80 mmHg',
#   'Pulmonary artery pressure (at rest) (syst/diast):   19/7 cmH2O',
# ...

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre',sampfrom=80000,
                           channels=[1,3],return_res=64)
wfdb.plot_wfdb(record)

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient083/s0272lre',sampfrom=80000,
                           channels=[1,3],return_res=64)
wfdb.plot_wfdb(record)

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre',sampfrom=80000,
                           channels=[1],return_res=64)
wfdb.plot_wfdb(record)

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre',sampfrom=80000,
                           channels=[1,3],return_res=64)
wfdb.plot_wfdb(record)

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre',
                           sampfrom=8000,channels=[1,3],return_res=64)
wfdb.plot_wfdb(record)

# %%
record = wfdb.rdrecord('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre',
                           channels=[1],return_res=32)
wfdb.plot_wfdb(record)

# %%
ann = wfdb.rdann('/home/tkrsh/ptb-diagnostic-ecg-database-1.0.0/patient019/s0058lre', 'hea', sampto=300000)
